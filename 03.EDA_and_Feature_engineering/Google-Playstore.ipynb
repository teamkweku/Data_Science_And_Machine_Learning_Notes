# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('googleplaystore.csv')
df.sample(10)
# Out:
#                                                      App            Category  \
# 4285                           KIM KARDASHIAN: HOLLYWOOD                GAME
# 3635                                Weather Radar Widget             WEATHER
# 5795                                    Axe Champs! Wars                GAME
# 8892                                               dt.se  NEWS_AND_MAGAZINES
# 2962                                          MLB At Bat              SPORTS
# 10427                             IKORO FH App Rosenheim              FAMILY
# 10226  Video Downloader for FB : Video Download with ...       VIDEO_PLAYERS
# 2902         Square InPic - Photo Editor & Collage Maker         PHOTOGRAPHY
# 7989                                       The CW TV app              FAMILY
# 5438                                           3D Tennis              SPORTS
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 4285      4.3  1017408                 34M  10,000,000+  Free     0
# 3635      4.3    18194                3.2M   1,000,000+  Free     0
# 5795      5.0        8                 25M          50+  Free     0
# 8892      3.1      124                 12M      10,000+  Free     0
# 2962      4.2    82882  Varies with device   5,000,000+  Free     0
# 10427     NaN       22                 29M       1,000+  Free     0
# 10226     4.5     1060                3.2M     100,000+  Free     0
# 2902      4.4   635846                 14M  50,000,000+  Free     0
# 7989      3.2       24                4.8M       5,000+  Free     0
# 5438      4.2  1008012                 13M  50,000,000+  Free     0
#
#       Content Rating                   Genres       Last Updated  \
# 4285            Teen                Adventure      July 16, 2018
# 3635        Everyone                  Weather      June 28, 2017
# 5795        Everyone                   Arcade      June 26, 2018
# 8892        Everyone         News & Magazines      June 29, 2018
# 2962        Everyone                   Sports      July 30, 2018
# 10427       Everyone                Education   February 6, 2018
# 10226       Everyone  Video Players & Editors  December 20, 2017
# 2902        Everyone              Photography       May 23, 2018
# 7989        Everyone            Entertainment      July 28, 2018
# 5438        Everyone                   Sports   December 5, 2017
#
#               Current Ver         Android Ver
# 4285                9.2.0          4.0 and up
# 3635                1.7.7          3.0 and up
# 5795                  1.1          4.1 and up
# 8892                4.9.0          4.1 and up
# 2962   Varies with device  Varies with device
# 10427            1.10.0.0        2.3.3 and up
# 10226                 2.1          4.0 and up
# 2902               4.2.14          4.0 and up
# 7989                  1.1          3.2 and up
# 5438                1.7.7          2.1 and up

# %% [markdown]
# #### Steps to typically follow with every dataset
# 1. Data Cleaning
# 2. Exploratory Data Analysis (EDA)
# 3. Feature Engineering

# %%
### Basic dataset information gathering and observation
df.info()
df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            10841 non-null  str
#  5   Installs        10841 non-null  str
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Current Ver     10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 1.1 MB
# (10841, 13)

# %%
### Checking for any missing values in your dataset
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# #### Handling Missing Values Column by Column and cleaning the dataset

# %%
### 1. Starting with reviews
### First we would want to check if all values in the reviews column though str are numeric in nature
### Also Reviews don't have any missing values to start with
print(df['Reviews'].str.isnumeric().sum())
# Out:
# 10840

# %%
### Throwing the error for the different field in the Reviews row
df['Reviews'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 ### Throwing the error for the different field in the Reviews row
# ----> 2 df['Reviews'].astype(int)
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/internals/managers.py:614, in BaseBlockManager.astype(self, dtype, errors)
#     613 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 614     return self.apply("astype", dtype=dtype, errors=errors)
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/internals/managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/internals/blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/arrays/string_.py:946, in StringArray.astype(self, dtype, copy)
#     943     values[mask] = np.nan
#     944     return values
# --> 946 return super().astype(dtype, copy)
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/arrays/numpy_.py:280, in NumpyExtensionArray.astype(self, dtype, copy)
#     277         return self.copy()
#     278     return self
# --> 280 result = astype_array(self._ndarray, dtype=dtype, copy=copy)
#     281 return result
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/envs/eda/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or object in (arr.dtype, dtype):
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '3.0M'

# %%
### 10840 out of 10841 means one of the fields is not numeric by nature
### hence we need to find out how
### we can text by trying to convert all the fields to int and see what throws the error or check which is not numeric
df[~df['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
### Now you have the decision of converting to thousands or droping the record completely
## But first lets make a copy of the dataset and work on the copy from now on
df_copy=df.copy()

# %%
#### Drop just that row from the dataset
df_copy=df_copy.drop(index=[10472])

###
df_copy[~df_copy['Reviews'].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
#### Convert the reviews feature to integer
df_copy['Reviews']=df_copy['Reviews'].astype(int)

# %%
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  str
#  1   Category        10840 non-null  str
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  str
#  5   Installs        10840 non-null  str
#  6   Type            10839 non-null  str
#  7   Price           10840 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10840 non-null  str
#  10  Last Updated    10840 non-null  str
#  11  Current Ver     10832 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), int64(1), str(11)
# memory usage: 1.2 MB

# %%
#### Handling the Size feature next
### Size has both M-Megabyte and k-Kilobyte. Hence we need to convert to one particular datatype 
df_copy['Size'].unique()
# Out:
# <StringArray>
# [  '19M',   '14M',  '8.7M',   '25M',  '2.8M',  '5.6M',   '29M',   '33M',
#   '3.1M',   '28M',
#  ...
#   '467k',  '157k',   '44k',  '676k',   '67k',  '552k',  '885k', '1020k',
#   '582k',  '619k']
# Length: 461, dtype: str

# %% [markdown]
# ##### Thought Process: Cleaning the Size Column
#
# `Step 1: Inspect the raw data first`
#
# The Google Play Store Size column typically looks like this:
# ['19M', '14M', '8.7M', '25M', '2.8M', '512k', '3.0M', 'Varies with device', ...]
#
# *Key observations from this inspection:*
#
# Values are strings, not numbers.
# Sizes are mixed units: M (Megabytes) and k (Kilobytes).
# There's a non-numeric category: "Varies with device" — this isn't missing data (NaN), but it's not a usable number either. You need a strategy for it.
#
# This inspection step is critical — you should never blindly write a conversion function before knowing what all the unique values look like. Skipping this is how you get silent bugs or NaN explosions later.
#
# `Step 2: Decide on target unit`:
#
# *Reasoning*: You need one consistent unit to make the column numeric and comparable. You have two choices:
#
# Convert everything to `KB (kilobytes)` — avoids fractional values since M → K is multiplying by 1024 (or 1000).
# Convert everything to `MB` — keeps numbers smaller/more interpretable, but K → M creates decimals (e.g., 512k → 0.5M).
#
# Either is valid. I'll standardize to KB here since it avoids introducing decimals from the smaller unit, but the logic is symmetric if you prefer MB.
#
#
# `Step 3: Decide what to do with "Varies with device"`
#
# This is a feature engineering decision, not just cleaning:
#
# Option A: Convert to`NaN` and impute later (e.g., median size, or median size grouped by Category).
# Option B: Create a separate binary flag column (Size_Varies = 1) before nulling it out — because "varies with device" might itself carry signal (e.g., apps with device-dependent size might behave differently, like games vs. utility apps).
#
# I'd recommend Option B — it preserves information rather than discarding it.`
#
# `Step 4: Write the conversion function`

# %%
def convert_size(size):
    if size == 'Varies with device':
        return np.nan
    elif size.endswith('M'):
        return float(size[:-1]) * 1024   # MB -> KB
    elif size.endswith('k'):
        return float(size[:-1])          # already in KB
    else:
        return np.nan  # catch any unexpected format

# %% [markdown]
# `Why write it as a function with explicit branches instead of a one-liner regex replace?`
#
# It's easier to read and debug.
# The else: return np.nan branch acts as a safety net — if the dataset has some unexpected format you didn't anticipate during Step 1, it won't crash your pipeline; it'll just surface as a NaN you can investigate.

# %%
### Step 5: Apply it and create the flag column first
df_copy['Size_Varies'] = (df_copy['Size'] == 'Varies with device').astype(int)
# Out:
#                     App             Category  Rating  Reviews  Size  \
# 10709  FO AIRBUS Nantes        COMMUNICATION     NaN        0   17M
# 7735         CQ Ukraine         PRODUCTIVITY     NaN        0  9.1M
# 5319    Al-Quran (Free)  BOOKS_AND_REFERENCE     4.6   218451  4.7M
# 3816        Google News   NEWS_AND_MAGAZINES     3.9   877643   13M
# 6891        Philips Hue            LIFESTYLE     3.1    10006   53M
#
#              Installs  Type Price Content Rating             Genres  \
# 10709            100+  Free     0       Everyone      Communication
# 7735              10+  Free     0       Everyone       Productivity
# 5319      10,000,000+  Free     0       Everyone  Books & Reference
# 3816   1,000,000,000+  Free     0           Teen   News & Magazines
# 6891       1,000,000+  Free     0       Everyone          Lifestyle
#
#             Last Updated Current Ver Android Ver  Size_Varies
# 10709  December 14, 2017         1.0  4.1 and up            0
# 7735       June 25, 2018      1.17.0  4.1 and up            0
# 5319        May 20, 2018       3.2.3  4.0 and up            0
# 3816      August 1, 2018       5.2.0  4.4 and up            0
# 6891       July 26, 2018       3.2.0  5.0 and up            0

# %% [markdown]
# `Why do this?`
#
# Notice something interesting.
#
# Originally the information was stored as text:
#
# `Varies with device`
#
# But that text really represents a condition:
#
# Does the app have a fixed size?
#
# Yes or No.
#
# By creating Size_Varies, you've transformed a text category into a binary feature (0 or 1), which is much easier for many machine learning algorithms to use.

# %%
### After this step you can apply conversion
df_copy['Size'] = df_copy['Size'].apply(convert_size)

# %%
df_copy.sample(5)
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  str
#  1   Category        10840 non-null  str
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  str
#  6   Type            10839 non-null  str
#  7   Price           10840 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10840 non-null  str
#  10  Last Updated    10840 non-null  str
#  11  Current Ver     10832 non-null  str
#  12  Android Ver     10838 non-null  str
#  13  Size_Varies     10840 non-null  int64
# dtypes: float64(2), int64(2), str(10)
# memory usage: 1.2 MB

# %%
df_copy[['Size', 'Size_Varies']].sample(10)
# Out:
#          Size  Size_Varies
# 4159  52224.0            0
# 9868   4505.6            0
# 7393   6553.6            0
# 2202  12288.0            0
# 2538  14336.0            0
# 1136      NaN            1
# 1734  18432.0            0
# 4965   2969.6            0
# 2819  19456.0            0
# 1053  71680.0            0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            10841 non-null  str
#  5   Installs        10841 non-null  str
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Current Ver     10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 1.1 MB

# %%
### Step 7: Handle the resulting missing values
df_copy['Size'].isnull().sum()

df_copy[df_copy['Size'].isnull()]
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10725                                          Posta App  MAPS_AND_NAVIGATION
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
#        Rating  Reviews  Size     Installs  Type Price Content Rating  \
# 37        4.1    36639   NaN   5,000,000+  Free     0       Everyone
# 42        4.4   295221   NaN  10,000,000+  Free     0       Everyone
# 52        4.6    17057   NaN   1,000,000+  Free     0       Everyone
# 67        4.3    40211   NaN   5,000,000+  Free     0       Everyone
# 68        3.9      356   NaN     100,000+  Free     0       Everyone
# ...       ...      ...   ...          ...   ...   ...            ...
# 10713     4.4     3471   NaN     100,000+  Free     0       Everyone
# 10725     3.6        8   NaN       1,000+  Free     0       Everyone
# 10765     3.4      622   NaN     100,000+  Free     0     Mature 17+
# 10826     4.0    88486   NaN   5,000,000+  Free     0     Mature 17+
# 10839     4.5      114   NaN       1,000+  Free     0     Mature 17+
#
#                   Genres        Last Updated         Current Ver  \
# 37          Art & Design       July 14, 2018  Varies with device
# 42          Art & Design       July 30, 2018  Varies with device
# 52       Auto & Vehicles       July 30, 2018  Varies with device
# 67       Auto & Vehicles       July 30, 2018  Varies with device
# 68       Auto & Vehicles        May 25, 2018  Varies with device
# ...                  ...                 ...                 ...
# 10713            Weather       July 24, 2018  Varies with device
# 10725  Maps & Navigation  September 27, 2017  Varies with device
# 10765             Social        May 23, 2018  Varies with device
# 10826             Social      March 23, 2018  Varies with device
# 10839  Books & Reference    January 19, 2015  Varies with device
#
#               Android Ver  Size_Varies
# 37           2.3.3 and up            1
# 42     Varies with device            1
# 52     Varies with device            1
# 67     Varies with device            1
# 68     Varies with device            1
# ...                   ...          ...
# 10713  Varies with device            1
# 10725          4.4 and up            1
# 10765  Varies with device            1
# 10826  Varies with device            1
# 10839  Varies with device            1
#
# [1695 rows x 14 columns]

# %%
df_copy['Category'].unique()
# Out:
# <StringArray>
# [     'ART_AND_DESIGN',   'AUTO_AND_VEHICLES',              'BEAUTY',
#  'BOOKS_AND_REFERENCE',            'BUSINESS',              'COMICS',
#        'COMMUNICATION',              'DATING',           'EDUCATION',
#        'ENTERTAINMENT',              'EVENTS',             'FINANCE',
#       'FOOD_AND_DRINK',  'HEALTH_AND_FITNESS',      'HOUSE_AND_HOME',
#   'LIBRARIES_AND_DEMO',           'LIFESTYLE',                'GAME',
#               'FAMILY',             'MEDICAL',              'SOCIAL',
#             'SHOPPING',         'PHOTOGRAPHY',              'SPORTS',
#     'TRAVEL_AND_LOCAL',               'TOOLS',     'PERSONALIZATION',
#         'PRODUCTIVITY',           'PARENTING',             'WEATHER',
#        'VIDEO_PLAYERS',  'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION']
# Length: 33, dtype: str

# %% [markdown]
# ### Step 1: What's the problem we're trying to solve?
#
# Suppose your dataset looks like this:
#
# App	Category	Size_KB
# WhatsApp	Communication	25000
# Gmail	Communication	30000
# Zoom	Communication	NaN
# Candy Crush	Games	85000
# Subway Surfers	Games	90000
# Temple Run	Games	NaN
#
# Notice that Zoom and Temple Run have missing sizes.
#
# A simple approach would be:
#
# ```python
# df['Size_KB'] = df['Size'].fillna(0)
# ```
#
# This fills every missing value with the overall median.
#
# But is that reasonable?
#
# Communication apps tend to be much smaller than games. Giving both the same replacement value could distort the data.
#
# A better idea is:
#
# `Fill each missing size using the median size within its own category.`

# %%
df_copy.groupby('Category')

# %%
df_copy['Size'] = df_copy['Size'].fillna(
    df_copy.groupby('Category')['Size'].transform('median')
)

# %%
df_copy.info()
df_copy['Size'].isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  str
#  1   Category        10840 non-null  str
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  str
#  6   Type            10839 non-null  str
#  7   Price           10840 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10840 non-null  str
#  10  Last Updated    10840 non-null  str
#  11  Current Ver     10832 non-null  str
#  12  Android Ver     10838 non-null  str
#  13  Size_Varies     10840 non-null  int64
# dtypes: float64(2), int64(2), str(10)
# memory usage: 1.2 MB
# np.int64(0)

# %% [markdown]
# - This is the general pattern for any "messy mixed-unit string column": inspect unique values → choose a target unit → explicitly decide how to treat non-numeric categories → write an explicit conversion function with a safety-net else branch → verify → impute.
